# %% [markdown]
# # This is Python Tutorial

# %% [markdown]
# This is our first program in python: It is just started here

# %%
print("Heloo World!")
# Out:
# Heloo World!

# %% [markdown]
# # Variables

# %%
x = 3

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x00000201B51FB100>
# dataframe_hash         function    <function dataframe_hash at 0x00000201B7DC6E80>
# dtypes_str             function    <function dtypes_str at 0x00000201B7DC60C0>
# get_dataframes         function    <function get_dataframes at 0x00000201B7DC6CA0>
# getpass                module      <module 'getpass' from 'D<...>aconda\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'D<...>aconda\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x00000201B7DC7060>
# is_data_frame          function    <function is_data_frame at 0x00000201B7DC6DE0>
# json                   module      <module 'json' from 'D:\\<...>\Lib\\json\\__init__.py'>
# x                      int         3

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x = 5.7

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x00000201B7DC6CA0>
# dataframe_hash         function    <function dataframe_hash at 0x00000201B7DC6D40>
# dtypes_str             function    <function dtypes_str at 0x00000201B7DC6C00>
# get_dataframes         function    <function get_dataframes at 0x00000201B7DC7060>
# getpass                module      <module 'getpass' from 'D<...>aconda\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'D<...>aconda\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x00000201B51FB600>
# is_data_frame          function    <function is_data_frame at 0x00000201B7DC5E40>
# json                   module      <module 'json' from 'D:\\<...>\Lib\\json\\__init__.py'>
# x                      float       5.7

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x00000201B7DC5E40>
# dataframe_hash         function    <function dataframe_hash at 0x00000201B7DC6C00>
# dtypes_str             function    <function dtypes_str at 0x00000201B7DC6CA0>
# get_dataframes         function    <function get_dataframes at 0x00000201B7DC6D40>
# getpass                module      <module 'getpass' from 'D<...>aconda\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'D<...>aconda\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x00000201B7DC60C0>
# is_data_frame          function    <function is_data_frame at 0x00000201B51FB600>
# json                   module      <module 'json' from 'D:\\<...>\Lib\\json\\__init__.py'>
# x                      float       5.7

# %%
print(type(x))
# Out:
# <class 'float'>

# %%
abcd = 556.32

# %%
# %whos

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# abcd                   float       556.32
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x00000201B7DC7060>
# dataframe_hash         function    <function dataframe_hash at 0x00000201B51FB600>
# dtypes_str             function    <function dtypes_str at 0x00000201B7DC60C0>
# get_dataframes         function    <function get_dataframes at 0x00000201B7DC5E40>
# getpass                module      <module 'getpass' from 'D<...>aconda\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'D<...>aconda\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x00000201B7DC6DE0>
# is_data_frame          function    <function is_data_frame at 0x00000201B7DC6FC0>
# json                   module      <module 'json' from 'D:\\<...>\Lib\\json\\__init__.py'>
# x                      float       5.7

# %%
a,b,c,d,f = 3,5,6,7.2,-3

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# a                      int         3
# abcd                   float       556.32
# b                      int         5
# c                      int         6
# d                      float       7.2
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x00000201B7DC6C00>
# dataframe_hash         function    <function dataframe_hash at 0x00000201B7DC6FC0>
# dtypes_str             function    <function dtypes_str at 0x00000201B7DC6DE0>
# f                      int         -3
# get_dataframes         function    <function get_dataframes at 0x00000201B7DC7060>
# getpass                module      <module 'getpass' from 'D<...>aconda\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'D<...>aconda\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x00000201B8384220>
# is_data_frame          function    <function is_data_frame at 0x00000201B8384040>
# json                   module      <module 'json' from 'D:\\<...>\Lib\\json\\__init__.py'>
# x                      float       5.7

# %%
del abcd

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# a                      int         3
# b                      int         5
# c                      int         6
# d                      float       7.2
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x00000201B8384220>
# dataframe_hash         function    <function dataframe_hash at 0x00000201B7DC6C00>
# dtypes_str             function    <function dtypes_str at 0x00000201B8384040>
# f                      int         -3
# get_dataframes         function    <function get_dataframes at 0x00000201B7DC6DE0>
# getpass                module      <module 'getpass' from 'D<...>aconda\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'D<...>aconda\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x00000201B51FB740>
# is_data_frame          function    <function is_data_frame at 0x00000201B51FB600>
# json                   module      <module 'json' from 'D:\\<...>\Lib\\json\\__init__.py'>
# x                      float       5.7

# %%
print(abcd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 print(abcd)
#
# NameError: name 'abcd' is not defined

# %%
c = 2+4j

# %%
print(type(c))
# Out:
# <class 'complex'>

# %%
s = "hellow how are you"

# %%
print(type(s))
# Out:
# <class 'str'>

# %%
for k, v in globals().items():
    if isinstance(v, (int, float, str)):
        print(k, type(v), v)
# Out:
# __name__ <class 'str'> __main__
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 for k, v in globals().items():
#       2     if isinstance(v, (int, float, str)):
#       3         print(k, type(v), v)
#
# RuntimeError: dictionary changed size during iteration

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# a                      int         3
# b                      int         5
# c                      complex     (2+4j)
# d                      float       7.2
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x00000201B83844A0>
# dataframe_hash         function    <function dataframe_hash at 0x00000201B83859E0>
# dtypes_str             function    <function dtypes_str at 0x00000201B8385620>
# f                      int         -3
# get_dataframes         function    <function get_dataframes at 0x00000201B83842C0>
# getpass                module      <module 'getpass' from 'D<...>aconda\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'D<...>aconda\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x00000201B8385EE0>
# is_data_frame          function    <function is_data_frame at 0x00000201B8384E00>
# json                   module      <module 'json' from 'D:\\<...>\Lib\\json\\__init__.py'>
# k                      str         __name__
# s                      str         hellow how are you
# v                      str         __main__
# x                      float       5.7

# %%
del dataframe_columns
del dataframe_hash
del dtypes_str
del get_dataframes
del import_pandas_safely
del is_data_frame

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# a                      int         3
# b                      int         5
# c                      complex     (2+4j)
# d                      float       7.2
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x00000201B8385EE0>
# dataframe_hash         function    <function dataframe_hash at 0x00000201B83859E0>
# dtypes_str             function    <function dtypes_str at 0x00000201B8386700>
# f                      int         -3
# get_dataframes         function    <function get_dataframes at 0x00000201B83844A0>
# getpass                module      <module 'getpass' from 'D<...>aconda\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'D<...>aconda\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x00000201B8386520>
# is_data_frame          function    <function is_data_frame at 0x00000201B8384E00>
# json                   module      <module 'json' from 'D:\\<...>\Lib\\json\\__init__.py'>
# k                      str         __name__
# s                      str         hellow how are you
# v                      str         __main__
# x                      float       5.7

# %%
globals().clear()

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
for k, v in globals().items():
    if isinstance(v, (int, float, str)):
        print(k, type(v), v)
# Out:
# __name__ <class 'str'> __main__
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 for k, v in globals().items():
#       2     if isinstance(v, (int, float, str)):
#       3         print(k, type(v), v)
#
# RuntimeError: dictionary changed size during iteration

# %%
a = 3
b = 5
c = 6
d = 7.2
f = -3
x = 5.7

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# a                      int         3
# b                      int         5
# c                      int         6
# d                      float       7.2
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x000001C97359B9C0>
# dataframe_hash         function    <function dataframe_hash at 0x000001C97359BA60>
# dtypes_str             function    <function dtypes_str at 0x000001C97359B2E0>
# f                      int         -3
# get_dataframes         function    <function get_dataframes at 0x000001C974AF3EC0>
# getpass                module      <module 'getpass' from 'D<...>aconda\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'D<...>aconda\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x000001C97675D4E0>
# is_data_frame          function    <function is_data_frame at 0x000001C97675CCC0>
# json                   module      <module 'json' from 'D:\\<...>\Lib\\json\\__init__.py'>
# k                      str         __name__
# v                      str         __main__
# x                      float       5.7

# %% [markdown]
# # Operators

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x0000022C83734180>
# dataframe_hash         function    <function dataframe_hash at 0x0000022C83196D40>
# dtypes_str             function    <function dtypes_str at 0x0000022C837354E0>
# get_dataframes         function    <function get_dataframes at 0x0000022C83196F20>
# getpass                module      <module 'getpass' from 'D<...>aconda\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'D<...>aconda\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x0000022C83736F20>
# is_data_frame          function    <function is_data_frame at 0x0000022C83734E00>
# json                   module      <module 'json' from 'D:\\<...>\Lib\\json\\__init__.py'>

# %%
a = 3
b = 5

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# a                      int         3
# b                      int         5
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x0000022C83736F20>
# dataframe_hash         function    <function dataframe_hash at 0x0000022C83734180>
# dtypes_str             function    <function dtypes_str at 0x0000022C83734E00>
# get_dataframes         function    <function get_dataframes at 0x0000022C837354E0>
# getpass                module      <module 'getpass' from 'D<...>aconda\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'D<...>aconda\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x0000022C83737420>
# is_data_frame          function    <function is_data_frame at 0x0000022C837347C0>
# json                   module      <module 'json' from 'D:\\<...>\Lib\\json\\__init__.py'>

# %%
sumOfaAndb = a+b

# %%
print(sumOfaAndb)
# Out:
# 8

# %%
type(sumOfaAndb)
# Out:
# int

# %%
a = 3
b = 5
c = 6
d = 7.2
f = -3
x = 5.7

# %%
s1 = "hellow"
s2 = "world"
s = s1 + s2
print(s)
# Out:
# hellowworld

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x000001CE060DB7E0>
# dataframe_hash         function    <function dataframe_hash at 0x000001CE08D05EE0>
# dtypes_str             function    <function dtypes_str at 0x000001CE07637EC0>
# get_dataframes         function    <function get_dataframes at 0x000001CE08D06160>
# getpass                module      <module 'getpass' from 'D<...>aconda\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'D<...>aconda\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x000001CE060DAF20>
# is_data_frame          function    <function is_data_frame at 0x000001CE060DB420>
# json                   module      <module 'json' from 'D:\\<...>\Lib\\json\\__init__.py'>

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# a                      int         6
# b                      int         3
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x000001CE060DAF20>
# dataframe_hash         function    <function dataframe_hash at 0x000001CE060DB7E0>
# dtypes_str             function    <function dtypes_str at 0x000001CE060DB420>
# get_dataframes         function    <function get_dataframes at 0x000001CE07637EC0>
# getpass                module      <module 'getpass' from 'D<...>aconda\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'D<...>aconda\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x000001CE08D07100>
# is_data_frame          function    <function is_data_frame at 0x000001CE08D06F20>
# json                   module      <module 'json' from 'D:\\<...>\Lib\\json\\__init__.py'>

# %%
a = int(input())
b = int(input())
if a>b:
    print(a)
if b>a:
    print(b)
# Out:
#  10
#  67
# 67

# %%
a = int(input())
b = int(input())
if a>b:
    print(a)
if b>a:
    print(b)
# Out:
#  155
#  67
# 155

# %%
a = int(input())
b = int(input())
if a>b:
    print(a)
    print("if part")
else:
    print(b)
    print("else part")
# Out:
#  55
#  88
# 88
# else part

# %%
a = float(input("Enter first number:"))
b = float(input("Enter second number:"))
if b > a:
    print("b is greater than a")
elif a == b:
    print("a and b is equal")
else:
    print("a is greater than b")
# Out:
# Enter first number: 77
# Enter second number: 88
# b is greater than a

# %%
a = 10
b = 10
if a==b:
    print("Equal")
elif a>b:
    print("A")
else:
    print("B")
print("Not in if")
# Out:
# Equal
# Not in if

# %%
a = int(input("Enter the marks: "))
if a >= 85:
    print("A grade")
elif (a < 85) and (a >= 80):
    print("A - Grade")
elif a < 80 and a >= 75:
    print("B grade")
elif a < 75 and a >= 70:
    print("B - Grade")
else:
    print("Below Average")
# Out:
# Enter the marks:  64
# Below Average

# %%
a = 13
if a>10:
    print(">10")
elif not(a>10):
    print("Else part")
# Out:
# >10

# %%
a = int(input())
if a>10:
    print(">10")
    print("Inside the top if")
    if a>20:
        print(">20")
        print("Inside the nested if")
        if a>30:
            print(">30")
            print("inside the nested if of nested if")
        else:
            print("<=30")
            print("inside the else part of nested if of nested if")
    else:
        print("<=20")
        print("Inside the else part of nested if")
print("Outside all ifs")
# Out:
#  25
# >10
# Inside the top if
# >20
# Inside the nested if
# <=30
# inside the else part of nested if of nested if
# Outside all ifs

# %%
# single line comment
""" 
User will enter a floating point number let say 238.915. Your task
is to find out the integer portion before the point (in this case 238)
and then check if that integer portion is an even number or not?
"""
x = float(input("Enter a real number :"))
y = round(x)
if x>0:    
    if y>x:
        intPortion = y-1 # 29.6
    else:
        intPortion = y
else:
    if y<x:
        intPortion = y+1
    else:
        intPortion = y

if intPortion%2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a real number : 81.88
# Odd

# %%
n = int(input())
i = 1
while i < n:
    print(i**2)
    print("This is iteration number :", i)
    i+=1 # i = i+1
print("Loop done")
# Out:
#  8
# 1
# This is iteration number : 1
# 4
# This is iteration number : 2
# 9
# This is iteration number : 3
# 16
# This is iteration number : 4
# 25
# This is iteration number : 5
# 36
# This is iteration number : 6
# 49
# This is iteration number : 7
# Loop done

# %%
n = 10
i = 1
while True:
    if i%9 == 0:
        print("Inside if")
        break
    else:
        print("inside Else")
        i = i+1 # i+=1
print("done")
# Out:
# inside Else
# inside Else
# inside Else
# inside Else
# inside Else
# inside Else
# inside Else
# inside Else
# Inside if
# done

# %%
n = 10
i = 1
while True:
    if i%9 != 0:
        print("inside if")
        i +=1
        continue
    print("something")
    print("somethingelse")
    break
    
print("done")
# Out:
# inside if
# inside if
# inside if
# inside if
# inside if
# inside if
# inside if
# inside if
# something
# somethingelse
# done

# %%
L = []
for i in range(1,20,3):
    print(i)
    L.append(i**2) 
print(L)
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19
# [1, 16, 49, 100, 169, 256, 361]

# %%
S = {"apple",4.9,"cherry"}
i = 1
for x in S:
    print(x)
    i+=1
    if i==3:
        break
    else:
        pass
else:
    print("Loop terminates with success")
print("Out side the loop")
# Out:
# cherry
# apple
# Out side the loop

# %%
D = {"A":10,"B":-19,"C":"abc"}
for x in D:
    print(x,D[x])
# Out:
# A 10
# B -19
# C abc

# %%
""" Given a list of numbers i.e. [1,2,4,-5,7,9,3,2], make another list
that contains all the items in sorted order from min to max. i.e. your 
result will be another list like [-5,1,2,2,3,7,9]
"""
L = [1,2,4,-5,7,9,3,2]
for j in range(len(L)):
    m = L[j]
    idx = j
    c = j
    for i in range(j,len(L)):
        if L[i]<m:
            m = L[i]
            idx = c
        c+=1    
    tmp = L[j]
    L[j] = m
    L[idx] = tmp
print(L)

# %%
""" Given a list of numbers i.e. [1,2,4,-5,7,9,3,2], make another list
that contains all the items in sorted order from min to max. i.e. your 
result will be another list like [-5,1,2,2,3,7,9]
"""
L = [1,2,4,-5,7,9,3,2]
for j in range(len(L)):
    m = L[j]
    idx = j
    c = j
    for i in range(j,len(L)):
        if L[i]<m:
            m = L[i]
            idx = c
        c+=1    
    tmp = L[j]
    L[j] = m
    L[idx] = tmp
print(L)
# Out:
# [-5, 1, 2, 2, 3, 4, 7, 9]

# %%
L
# Out:
# [-5, 1, 2, 2, 3, 4, 7, 9]

# %%
def printSucess():
    print("I am done")
    print("Send me another task")

# %%
printSucess()
# Out:
# I am done
# Send me another task

# %%
3+8
# Out:
# 11

# %%
def printSucess2():
    """ This function is doing nothing except printing a message.
    That message is "hellow"
    """
    print("hellow")

# %%
help(printSucess2)
# Out:
# Help on function printSucess2 in module __main__:
#
# printSucess2()
#     This function is doing nothing except printing a message.
#     That message is "hellow"

# %% [raw]
# printSuccess2()

# %%
def printMsg(msg):
    """ The function prints the message supplied by the user
    or prints that msg is not in the form of string"""
    
    if isinstance(msg,str):
        print(msg)
    else:
        print("Your input argument is not a string")
        print("Here is the type of what you have supplied :",type(msg))

# %%
printMsg?
# Out:
# Signature: printMsg(msg)
# Docstring:
# The function prints the message supplied by the user
# or prints that msg is not in the form of string
# File:      c:\users\hp\appdata\local\temp\ipykernel_10284\4554208.py
# Type:      function

# %%
printMsg("This is the message")
# Out:
# This is the message

# %%
printMsg(23)
# Out:
# Your input argument is not a string
# Here is the type of what you have supplied : <class 'int'>

# %%
y = "hellow there"
printMsg(y)
# Out:
# hellow there

# %%
def mypow(a,b):
    """ this function computes power just like builtin pow function"""
    c = a**b
    print(c)

# %%
mypow?

# %%
mypow(3,4)
# Out:
# 81

# %%
def checkArgs(a,b,c):
    if isinstance(a,(int,float)) and isinstance(b,(int,float)) and isinstance(c,(int,float)):
        print((a+b+c)**2)
    else:
        print("Error: the input arguements are not of the expected types")

# %%
checkArgs(3,4,5)
# Out:
# 144

# %%
checkArgs(3,4,"g")
# Out:
# Error: the input arguements are not of the expected types

# %%
def f(a,b,c):
    print("A is :",a)
    print("B is :",b)
    print("C is :",c)

# %%
#f(2,3,"game")
f(3,"game",2)
# Out:
# A is : 3
# B is : game
# C is : 2

# %%
def myadd(a,b):
    sumValue = a+b
    return sumValue

# %%
d=myadd(3,5)
print(d)
# Out:
# 8

# %%
def h():
    print("A")
    a = 3
    b = 5
    c = a+b
    print("something")
    return c
    print("B")
    print("C")

# %%
print(type(h()))
# Out:
# A
# something
# <class 'int'>

# %%
def r():
    a = 5
    b = 7
    d = "something"
    return a,b,d

# %%
x,y,z = r()
print(x,y,z)
# Out:
# 5 7 something

# %%
def myAddUniversal(*args):
    s = 0
    for i in range(len(args)):
        s += args[i] # s = s+args[i]
    return s

# %%
print(myAddUniversal(2,4,5,4.6,78))
# Out:
# 93.6

# %%
def printAllVariableNamesAndValues(**args):
    for x in args:
        print("Variable Name is :",x," And Value is :",args[x])

# %%
printAllVariableNamesAndValues(a=3, b="B",c="CCC",y=6.7)
# Out:
# Variable Name is : a  And Value is : 3
# Variable Name is : b  And Value is : B
# Variable Name is : c  And Value is : CCC
# Variable Name is : y  And Value is : 6.7

# %%
def gg(s=4):
    print(s)

# %%
gg()
# Out:
# 4

# %%
gg(56)
# Out:
# 56

# %%
L = [1,2,3]
L2 = L
L2[0] = -9
print(L)
# Out:
# [-9, 2, 3]

# %%
def ff(L=[1,2]):
    for i in L:
        print(i)

# %%
L2 = [12,3,4]
ff()
# Out:
# 1
# 2

# %%
ff(L2)
# Out:
# 12
# 3
# 4

# %%
import sys
sys.path.append('C:/ABC/')

# %%
import my_universal_functions as myfs
#from my_universal_functions import addAllNumerics

# %%
def addAllNumerics(*args):
    s = 0
    for x in args:
        s += x
    return s

# %%
d = addAllNumerics(2,3,4,5,6,7)
print(d)   # Output: 27
# Out:
# 27

# %%
c = myfs.addAllNumerics(2,3,4,6)

# %%
print(c)
# Out:
# 2

# %%
myfs.myName
# Out:
# 'Python Course'

# %%
""" Given a list of numbers i.e. [1,2,4,-5,7,9,3,2], make another list
that contains all the items in sorted order from min to max. i.e. your 
result will be another list like [-5,1,2,2,3,7,9]
"""
# Out:
# ' Given a list of numbers i.e. [1,2,4,-5,7,9,3,2], make another list\nthat contains all the items in sorted order from min to max. i.e. your \nresult will be another list like [-5,1,2,2,3,7,9]\n'

# %%
def findMin(L,startIndx):
    m = L[startIndx]
    idx = startIndx    
    for i in range(startIndx,len(L)):
        x = L[i]
        if x<m:
            m = x
            idx = i
        else:
            pass                
    return m,idx

# %%
a, b = findMin([2,3,4,0,9], 0)   # startIndx = 0
print(a, b)   # Output: 0 3
# Out:
# 0 3

# %%
def swapValues(L,idx1,idx2):
    tmp = L[idx1]
    L[idx1] = L[idx2]
    L[idx2] = tmp
    return L

# %%
L = [2,3,6,7]
L2 = swapValues(L,1,3)
print(L2)
# Out:
# [2, 7, 6, 3]

# %%
def checkIfNotNumeric2(L):
    for x in L:
        if not isinstance(x, (int, float)):
            return False
    return True

def sortList(L):
    if not(checkIfNotNumeric2(L)):
        print("Error: List does not contain numeric values")
        return
    return sorted(L)

# %%
L2 = sortList([2,1,5,3,-8,17])
print(L2)   # Output: [-8, 1, 2, 3, 5, 17]
# Out:
# [-8, 1, 2, 3, 5, 17]

# %%
checkIfNotNumeric??

# %%
print(checkIfNotNumeric2([2,1,5,3,8,17]))
# Out:
# True

# %%
s = "Python is a good language"
t = 'Its good for data science'

# %%
type(s)
# Out:
# str

# %%
print(s)
# Out:
# Python is a good language

# %%
print("hellow",12,"hellow2",'who are you',5.9)
# Out:
# hellow 12 hellow2 who are you 5.9

# %%
v = s+" "+t
print(v)
# Out:
# Python is a good language Its good for data science

# %%
price = 12
s = "The price of this book"
v = s + ' is: ' + str(price)
print(v)
print(s,"is:",price)
# Out:
# The price of this book is: 12
# The price of this book is: 12

# %%
a = """this is line 1
this is line 2
this is last line and this line is 3"""
print(a)
# Out:
# this is line 1
# this is line 2
# this is last line and this line is 3

# %%
print(""" The following options are available:
            -a       : does nothing
            -b       : also does nothing
""")
# Out:
#  The following options are available:
#             -a       : does nothing
#             -b       : also does nothing

# %%
s = "How are you and who are you"
print(s[5])
# Out:
# r

# %%
type(s[5])
# Out:
# str

# %%
s[0:10]
# Out:
# 'How are yo'

# %%
s[0:12:2]
# Out:
# 'Hwaeyu'

# %%
s
# Out:
# 'How are you and who are you'

# %%
# [start:end:step]
s[:12]
# Out:
# 'How are you '

# %%
s[::-1]
# Out:
# 'uoy era ohw dna uoy era woH'

# %%
a = "    abc def     hgq asdfaf     "
b = a.strip()
print(b)
# Out:
# abc def     hgq asdfaf

# %%
a = "ABC deFg ;; sadfa QF"
b = a.lower()
print(b)
# Out:
# abc defg ;; sadfa qf

# %%
c = a.upper()
print(c)
# Out:
# ABC DEFG ;; SADFA QF

# %%
d = a.replace(";","*")
print(d)
# Out:
# ABC deFg ** sadfa QF

# %%
d = a.replace(";","**&&^^%%")
print(d)
# Out:
# ABC deFg **&&^^%%**&&^^%% sadfa QF

# %%
a = "abc;def;hgydfa;yy23"
L = a.split(";")
print(L)
# Out:
# ['abc', 'def', 'hgydfa', 'yy23']

# %%
L[1]
# Out:
# 'def'

# %%
print(a.capitalize())
# Out:
# Abc;def;hgydfa;yy23

# %%
help(a.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
"abc" in "asdfafdjabcl;jfdopasdfoajfd;la"
# Out:
# True

# %%
print("we are learning \"string\" here")
# Out:
# we are learning "string" here

# %%
print("we are learning \"string\" here")
# Out:
# we are learning "string" here

# %%
print("c:\name\drive")
# Out:
# c:
# ame\drive

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\HP
